# %%
import numpy as np
import pandas as pd

# %%
csv_file = '/content/hk_restos_2025.csv'

# %%
df = pd.read_csv(csv_file)

# %%
df

# %%
#when the Reviewers equals to 0, we would not consider this restaurant!
df = df[df['Reviewers'] > 0]

# %%
df.tail()

# %%
#to split into different districts
# Central, Shun Hing Street, Mid-Levels, Sheung Shui, Shun Hing St -> , Tin Shui Wai, Shueng Wai, Fanling/ FANLING, Tuen Mun, Yuen Long, Tung Chung, Tai PO, Ma On Shan, Tai Wo, Sai Kung, Sha Tin / Shatin/ SHATIN, Discoversy Bay, Shek Mun, Hang Hau, Tseung Kwan O, Tsuen Wan, Po Lam,  Tai Wai/ TAI WAI, Tsang Yi,  Chai Wan,
# Lei Yue Mun, Yau Tong, Lam Tin, Ngau Chi Wan, Wong Tai Sin, Diamond Hill, Kwun Tong, San Po Kong, Kowloon Bay, Shau Kei Wan, Lok Fu, Lok Fu, Mei Foo, Cheung Sha Wan, Lai Chi Kok, Western District,
# Sai Wan Ho, Repulse Bay,Kowloon City, Quarry Bay, Shek Kip Mei,Tai Koo, Quarry Bay, To Kwa Wan, Mongkok, Prince Edward,Shek Tong Tsui,  Wan Chai, Sai Ying Pun,  Sheung Wan, Sham Shui Po,
# North Point, Tai Kok Tsui, Hung Hom, Ho Man Tin, Ap Lei Chau, Aberdeen, Pok Fu Lam, Fortress Hill, Wong Chuk Hang, Tin Hau, Causeway Bay, Tin Wan, Happy Valley, Jordan, Kennedy Town, Tsim Sha Tsui,
# if there are not suitable words for classifying, so it means that the location is not in the city or the busy area ()
# what about if the location has shown two distrits
# Define a mapping of keywords to districts
district_mapping = {
    'Central': 'Central',
    'Shun Hing St': 'Shun Hing Street',
    'Mid-Levels': 'Mid-Levels',
    'Sheung Shui': 'Sheung Shui',
    'Shun Hing St': 'Shun Hing Street',
    'Tin Shui Wai': 'Tin Shui Wai',
    'Shueng Wai': 'Shueng Wai',
    'Shueng Shui':'Sheung Wan',
    'Fanling': 'Fanling',
    'fANLING': 'Fanling',
    'Tuen Mun': 'Tuen Mun',
    'Yuen Long': 'Yuen Long',
    'Tung Chung': 'Tung Chung',
    'Tai Po': 'Tai Po',
    'Ma On Shan': 'Ma On Shan',
    'Tai Wo': 'Tai Wo',
    'Sai Kung': 'Sai Kung',
    'Sha Tin': 'Sha Tin',
    'Shatin': 'Sha Tin',
    'SHA TIN': 'Sha Tin',
    'Discovery Bay': 'Discovery Bay',
    'Shek Mun': 'Shek Mun',
    'Hang Hau': 'Hang Hau',
    'Tseung Kwan O': 'Tseung Kwan O',
    'Tsuen Wan': 'Tsuen Wan',
    'Po Lam': 'Po Lam',
    'Tai Wai': 'Tai Wai',
    'Tsang Yi': 'Tsang Yi',
    'Chai Wan': 'Chai Wan',
    'Lei Yue Mun': 'Lei Yue Mun',
    'Yau Tong': 'Yau Tong',
    'Lam Tin': 'Lam Tin',
    'Ngau Chi Wan': 'Ngau Chi Wan',
    'Wong Tai Sin': 'Wong Tai Sin',
    'Diamond Hill': 'Diamond Hill',
    'Kwun Tong': 'Kwun Tong',
    'San Po Kong': 'San Po Kong',
    'Kowloon Bay': 'Kowloon Bay',
    'Shau Kei Wan': 'Shau Kei Wan',
    'Lok Fu': 'Lok Fu',
    'Mei Foo': 'Mei Foo',
    'Cheung Sha Wan': 'Cheung Sha Wan',
    'Lai Chi Kok': 'Lai Chi Kok',
    'Western District': 'Western District',
    'Sai Wan Ho': 'Sai Wan Ho',
    'Repulse Bay': 'Repulse Bay',
    'Kowloon City': 'Kowloon City',
    'Quarry Bay': 'Quarry Bay',
    'Shek Kip Mei': 'Shek Kip Mei',
    'Tai Koo': 'Tai Koo',
    'To Kwa Wan': 'To Kwa Wan',
    'Mongkok': 'Mong Kok',
    'Prince Edward': 'Prince Edward',
    'Shek Tong Tsui': 'Shek Tong Tsui',
    'Wan Chai': 'Wan Chai',
    'Sai Ying Pun': 'Sai Ying Pun',
    'Sheung Wan': 'Sheung Wan',
    'Sham Shui Po': 'Sham Shui Po',
    'North Point': 'North Point',
    'Tai Kok Tsui': 'Tai Kok Tsui',
    'Hung Hom': 'Hung Hom',
    'Ho Man Tin': 'Ho Man Tin',
    'Ap Lei Chau': 'Ap Lei Chau',
    'Aberdeen': 'Aberdeen',
    'Pok Fu Lam': 'Pok Fu Lam',
    'Fortress Hill': 'Fortress Hill',
    'Wong Chuk Hang': 'Wong Chuk Hang',
    'Tin Hau': 'Tin Hau',
    'Causeway Bay': 'Causeway Bay',
    'Tin Wan': 'Tin Wan',
    'Happy Valley': 'Happy Valley',
    'Jordan': 'Jordan',
    'Kennedy Town': 'Kennedy Town',
    'Tsim Sha Tsui': 'Tsim Sha Tsui',
    'CENTRAL': 'Central',
    'SHUN HING STREET': 'Shun Hing Street',
    'MID-LEVELS': 'Mid-Levels',
    'SHEUNG SHUI': 'Sheung Shui',
    'SHUN HING ST': 'Shun Hing Street',
    'TIN SHUI WAI': 'Tin Shui Wai',
    'SHUENG WAI': 'Shueng Wan',
    'FANLING': 'Fanling',
    'TUEN MUN': 'Tuen Mun',
    'YUEN LONG': 'Yuen Long',
    'TUNG CHUNG': 'Tung Chung',
    'TAI PO': 'Tai Po',
    'MA ON SHAN': 'Ma On Shan',
    'TAI WO': 'Tai Wo',
    'SAI KUNG': 'Sai Kung',
    'SHA TIN': 'Sha Tin',
    'SHATIN': 'Sha Tin',
    'KWAI CHUNG':'Kwai Chung',
    'DISCOVERY BAY':'Discovery Bay',
    'SHEK MUN': 'Shek Mun',
    'HANG HAU': 'Hang Hau',
    'TSEUNG KWAN O': 'Tseung Kwan O',
    'TSUEN WAN': 'Tsuen Wan',
    'PO LAM': 'Po Lam',
    'TAI WAI': 'Tai Wai',
    'TSANG YI': 'Tsang Yi',
    'CHAI WAN': 'Chai Wan',
    'LEI YUE MUN': 'Lei Yue Mun',
    'YAU TONG': 'Yau Tong',
    'LAM TIN': 'Lam Tin',
    'NGAU CHI WAN': 'Ngau Chi Wan',
    'WONG TAI SIN': 'Wong Tai Sin',
    'DIAMOND HILL': 'Diamond Hill',
    'KWUN TONG': 'Kwun Tong',
    'SAN PO KONG': 'San Po Kong',
    'KOWLOON BAY': 'Kowloon Bay',
    'SHAU KEI WAN': 'Shau Kei Wan',
    'LOK FU': 'Lok Fu',
    'MEI FOO': 'Mei Foo',
    'CHEUNG SHA WAN': 'Cheung Sha Wan',
    'LAI CHI KOK': 'Lai Chi Kok',
    'WESTERN DISTRICT': 'Western District',
    'SAI WAN HO': 'Sai Wan Ho',
    'REPULSE BAY': 'Repulse Bay',
    'KOWLOON CITY': 'Kowloon City',
    'QUARRY BAY': 'Quarry Bay',
    'SHEK KIP MEI': 'Shek Kip Mei',
    'TAI KOO': 'Tai Koo',
    'TO KWA WAN': 'To Kwa Wan',
    'MONGKOK': 'Mong Kok',
    'PRINCE EDWARD': 'Prince Edward',
    'SHEK TONG TSUI': 'Shek Tong Tsui',
    'WAN CHAI': 'Wan Chai',
    'SAI YING PUN': 'Sai Ying Pun',
    'SHEUNG WAN': 'Sheung Wan',
    'SHAM SHUI PO': 'Sham Shui Po',
    'NORTH POINT': 'North Point',
    'TAI KOK TSUI': 'Tai Kok Tsui',
    'HUNG HOM': 'Hung Hom',
    'HO MAN TIN': 'Ho Man Tin',
    'AP LEI CHAU': 'Ap Lei Chau',
    'ABERDEEN': 'Aberdeen',
    'POK FU LAM': 'Pok Fu Lam',
    'FORTRESS HILL': 'Fortress Hill',
    'WONG CHUK HANG': 'Wong Chuk Hang',
    'TIN HAU': 'Tin Hau',
    'CAUSEWAY BAY': 'Causeway Bay',
    'TIN WAN': 'Tin Wan',
    'HAPPY VALLEY': 'Happy Valley',
    'JORDAN': 'Jordan',
    'KENNEDY TOWN': 'Kennedy Town',
    'TSIM SHA TSUI': 'Tsim Sha Tsui',
    'Kai Tak':'Kai Tak',
    'KAI TAK':'Kai Tak',
    'shum shui po':'Shum Shui Po',
    'Lai Chi Lok':'Lai Chi Kok',
    'Admiralty':'Admiralty',
    'The Peak':'The Peak',
    'Wing Lok Street':'Sheung Wan',
    'Wai Chai':'Wan Chai',
    'Sai Wan':'Sai Wan',
    'Tai Hang':'Tai Hang',
    'Yau Ma Tei':'Yau Ma Tei',
    'YAU MA TEI':'Yau Ma Tei',
    'Old Main Street':'Aberdeen',
    'Mong Kok':'Mong Kok',
    'MONG KOK':'Mong Kok',
    'Ngau Tau Kok':'Ngau Tau Kok',
    'Hung To Road':'Kwun Tong',
    'HANG ON STREET KOWLOON':'Kwun Tong',
    'Tsing Yi':'Tsing Yi',
    'TSING YI':'Tsing Yi',
    'Tsz Wan Shan':'Tsz Wan Shan',
    'Stanley':'Stanley',
    'Po Tat':'Po Tat',
    'Kwai Fong':'Kwai Fong',
    'Kwai Fong':'Kwai Fong',
    'Kwai Hing':'Kwai Hing',
    'Siu Sai Wan':'Siu Sai Wan',
    'TAI WA':'Tai Wai',
    'Tai Wa':'Tai Wai',
    'Pak Shek Kok':'Pak Shek Kok',
    'Ma On Shan':'Ma On Shan',
    'Tai Hang':'Tai Hang',
    'shum shui po':'Shum Shui Po',
    'Kowloon Tong':'Kowloon Tong',
    'Ngau Tau Kok':'Ngau Tau Kok',
    'Hung To Road':'Kwun Tong',
    'Hammer Hill':'Kai Tak',
    'Heng Fa Chuen':'Heng Fa Chuen',
    'Po Tat':'Po Tat',
    'Shueng Shui':"Sheung Shui",
    'Sham Tseng':'Sham Tseng',
    'Kwai Chung':'Kwai Chung',
    'KOWLOON TONG':'Kowloon Tong',
    'Choi Hung':'Choi Hung',
    'Shum Shui Po':'Shum Shui Po',
    'Fo Tan':'Fo Tan',
    'FO TAN':'Fo Tan',
    'Lockhart Road':'Wan Chai',
    'Kam Tin':'Kam Tin',
    'SHUM SHUI PO':'Shum Shui Po',
    'Cheung Sha Wan':'Cheung Sha Wan',
    'Chek Lap Kok':'Chek Lap Kok'

}

# %%
def get_district(location):
    for keyword in district_mapping.keys():
        if keyword in location:  # Check if the keyword is in the location
            return district_mapping[keyword]
    return None

# %%
df['District'] = df['Location'].apply(get_district)

# %%
df

# %%
# Filter the DataFrame for rows where 'District' is None
none_districts = df[df['District'].isnull()]

# Display the rows with None in 'District'
print(none_districts[['Location', 'District']].to_string(index=False))

# %%
# Assuming you have already created the 'District' column
# Display the first few rows of the DataFrame to see the 'District' column
print(df[['Location', 'District']].head())

# Optionally, you can display the entire DataFrame or a specific number of rows
# print(df[['Location', 'District']])  # Uncomment to see the full DataFrame

# %%
# Display unique districts
unique_districts = df['District'].unique()
print("Unique Districts:", unique_districts)

# Count occurrences of each district
district_counts = df['District'].value_counts()
print(district_counts)

# %%
# Filter the DataFrame for rows where 'District' is None
none_districts = df[df['District'].isnull()]

# Display the rows with None in 'District'
print(none_districts[['Location', 'District']].to_string(index=False))

# %%
# Filter the DataFrame to exclude rows where 'District' is None
df = df[df['District'].notnull()]

# Save the filtered DataFrame to a new CSV file
new_file = 'hk_restos_without_none_district.csv'
df.to_csv(new_file, index=False)

print(f"Filtered data without None in 'District' saved to {new_file}")
